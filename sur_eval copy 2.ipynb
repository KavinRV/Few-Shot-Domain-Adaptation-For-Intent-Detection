# %%
# !nvidia-smi
# Out:
# Fri Oct 13 14:29:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.191.01   Driver Version: 450.191.01   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   27C    P0    44W / 300W |      5MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   32C    P0    56W / 300W |   5453MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-SXM2...  On   | 00000000:0A:00.0 Off |                    0 |
# | N/A   33C    P0    58W / 300W |  31689MiB / 32510MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-SXM2...  On   | 00000000:0B:00.0 Off |                    0 |
# | N/A   26C    P0    44W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100-SXM2...  On   | 00000000:85:00.0 Off |                    0 |
# | N/A   28C    P0    44W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100-SXM2...  On   | 00000000:86:00.0 Off |                    0 |
# | N/A   30C    P0    44W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100-SXM2...  On   | 00000000:89:00.0 Off |                    0 |
# | N/A   34C    P0    60W / 300W |  31688MiB / 32510MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla V100-SXM2...  On   | 00000000:8A:00.0 Off |                    0 |
# | N/A   28C    P0    42W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    1   N/A  N/A   1312490      C   ...onda3/envs/wow/bin/python     5449MiB |
# |    2   N/A  N/A   3167101      C   python                          31685MiB |
# |    6   N/A  N/A   3169481      C   python                          31681MiB |
# +-----------------------------------------------------------------------------+

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

# %%
from datasets import Dataset, DatasetDict
from transformers import XLMRobertaForSequenceClassification, XLMRobertaConfig, XLMRobertaTokenizer, TrainingArguments, Trainer, DataCollatorWithPadding, AutoTokenizer, AutoModelForSequenceClassification
from transformers.models.xlm_roberta.modeling_xlm_roberta import XLMRobertaClassificationHead
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
import datasets
from typing import Optional
from transformers.modeling_outputs import SequenceClassifierOutput
from transformers.trainer import is_datasets_available, seed_worker
from datasets import load_dataset

# %%
# from datasets import load_dataset
# tokenized_sur = load_dataset("carnival13/test_DA_tokenized2")

# %%
model_ckpt = "xlmr_eng_sur_hard_curr_ep3_corr/checkpoint-510"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

# %%
import json
sur_df = {"indoml_id": [], "id": [], "utt": [], "intent": []}
id2ut = {}
lst = []

# Open the file for reading
with open('surprise.data', 'r') as file:
    # Iterate through each line in the file
    for line in file:
        # Parse the JSON data in each line
        data = json.loads(line)
        assert data["id"] not in id2ut.keys()
        lst.append(int(data["id"]))
        id2ut[data["id"]] = data["utt"]

        for k, v in data.items():
            sur_df[k].append(v)

# %%
with open('surprise.solution', 'r') as file:
    for i, line in enumerate(file):
        data = json.loads(line)
        assert lst[i] == int(data["indoml_id"][9:])
        # print(data.keys())
        sur_df["intent"].append(data["intent"])

# %%
from datasets import Dataset

def dict_to_dataset(dict):
    dataset = Dataset.from_dict(dict)
    return dataset

dataset = dict_to_dataset(sur_df)

# %%
dataset["intent"][0]
# Out:
# 'accept reservations'

# %%
int2eg = {}
dup_int = []
for eg in dataset:
    try:
        if eg["utt"] in int2eg[eg["intent"]]:
            # dup_int.append[eg["intent"]]
            continue
        int2eg[eg["intent"]].append(eg["utt"])
    except:
        int2eg[eg["intent"]] = [eg["utt"]]

# %%
import random

# samples examples from an intent
def few_sample(intent, l):
    num = l
    few = random.sample(int2eg[intent], num)
    random.shuffle(few)
    return few

# %%
int2id = {k:i for i, k in enumerate(int2eg.keys())}

# %%
# int2id

# %%
from tqdm import tqdm

train_new = {"query": [], "positive": [], "intent": [], "negatives": []}

# for each eg in the dataset
for eg in tqdm(dataset):
    if eg["utt"] in train_new["query"]:
        continue

    # add utterance to query
    train_new["query"].append(eg["utt"])
    # get the index of the utterance
    val = int2eg[eg["intent"]].index(eg["utt"])
    # get everything before the utterance and after the utterance except itself
    l = int2eg[eg["intent"]][:val]+int2eg[eg["intent"]][val+1:]

    neg_int_dict = {}
    for k, v in int2eg.items():
      if k == eg["intent"]:
          neg_int_dict[k] = v[val:] + v[val+1:]
          
      neg_int_dict[k] = random.sample(v, min(len(v), len(l)))

    negatives = list(neg_int_dict.values())
    train_new["positive"].append(int2id[eg["intent"]])

    train_new['intent'].append(list(neg_int_dict.keys()))
    # train_new['intent'].append(label2id_dict[eg['intent']])
    train_new['negatives'].append(negatives)
# Out:
# 100%|██████████| 2248/2248 [00:03<00:00, 649.35it/s]

# %%
from datasets import Dataset, load_dataset


def dict_to_dataset(dict):
    dataset = Dataset.from_dict(dict)
    return dataset

sur_dataset = dict_to_dataset(train_new)

# %%
def tokenize(df):
    out = {"pass_label": [], "input": []}
    for i, _ in enumerate(df["query"]):

        for ps, neg in enumerate(df["negatives"][i]):
            input = "query: " + df["query"][i] + " intent: " + df["intent"][i][ps].replace("_", " ") + " examples: " + " <sep> ".join(neg)
            out["input"].append(input)
            out["pass_label"].append(df["positive"][i])

    return out

# %%
sur_dataset_large = sur_dataset.map(tokenize, batched=True, remove_columns=sur_dataset.column_names)
# Out:
# Map:   0%|          | 0/2239 [00:00<?, ? examples/s]

# %%
def apply_token(df):
    return tokenizer(df["input"], max_length = 512, truncation=True, padding=False)

# %%
tokenized_sur_dataset = sur_dataset_large.map(apply_token, batched=True)
# Out:
# Map:   0%|          | 0/335850 [00:00<?, ? examples/s]

# %%
tokenized_sur_dataset = tokenized_sur_dataset.remove_columns(["input"])

# %% [markdown]
# #Evaluation

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Fri Oct 13 14:31:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.191.01   Driver Version: 450.191.01   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   26C    P0    44W / 300W |      5MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   31C    P0    57W / 300W |   5453MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-SXM2...  On   | 00000000:0A:00.0 Off |                    0 |
# | N/A   32C    P0    58W / 300W |  31689MiB / 32510MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-SXM2...  On   | 00000000:0B:00.0 Off |                    0 |
# | N/A   26C    P0    44W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100-SXM2...  On   | 00000000:85:00.0 Off |                    0 |
# | N/A   27C    P0    44W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100-SXM2...  On   | 00000000:86:00.0 Off |                    0 |
# | N/A   29C    P0    44W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100-SXM2...  On   | 00000000:89:00.0 Off |                    0 |
# | N/A   33C    P0    59W / 300W |  31688MiB / 32510MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla V100-SXM2...  On   | 00000000:8A:00.0 Off |                    0 |
# | N/A   28C    P0    42W / 300W |      3MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    1   N/A  N/A   1312490      C   ...onda3/envs/wow/bin/python     5449MiB |
# |    2   N/A  N/A   3167101      C   python                          31685MiB |
# |    6   N/A  N/A   3169481      C   python                          31681MiB |
# +-----------------------------------------------------------------------------+

# %%
class ReRanker(XLMRobertaForSequenceClassification):
    def __init__(self, config: XLMRobertaConfig):
        # config.rank_score_index = 32019
        config.n_pass = 10
        # config.output_hidden_states = True
        super().__init__(config)
#         self.rank_head = nn.Linear(config.d_model, config.vocab_size, bias=False)
        # self.rank_id = config.rank_score_index
        self.n_pass = config.n_pass


    def forward(self, input_ids=None, attention_mask=None, labels=None, pass_label=None, **kwargs):

        batch_size_n, seq_len = input_ids.size()
        batch_size = int(batch_size_n/self.n_pass)
        labels = None


        out = super().forward(input_ids=input_ids, attention_mask=attention_mask, **kwargs)
#         rank_score = self.rank_head(out.decoder_hidden_states[-1][:, 0, :])
        rank_score = out.logits.view(batch_size, -1)
        loss = None


        if pass_label != None:
            pass_label = pass_label[::self.n_pass]
            rank_score = rank_score
#             gen_score = out.gpe_score

            loss_fct1 = nn.CrossEntropyLoss()
#             loss_fct2 = nn.CrossEntropyLoss()

            rank_loss = loss_fct1(rank_score, pass_label.view(-1))
#             gen_loss = loss_fct2(gen_score, pass_label.view(-1))

#             loss = rank_loss + gen_loss

            loss = rank_loss
            # wandb.log({"loss": loss})

        ret =  SequenceClassifierOutput(
            loss=loss,
            logits=out.logits,
            hidden_states=out.hidden_states,
            attentions=out.attentions
        )
        ret.rank_score = rank_score
        return ret

# %%
model = ReRanker.from_pretrained(model_ckpt)

# %%
device = "cuda:7" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cuda:7'

# %%
tokenized_sur_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "pass_label"])

# %%
# help(tokenizer.decode)

# %%
# tokenizer.decode(tokenized_sur["train"][3]["input_ids"], skip_special_tokens=True)

# %%
data_collator = DataCollatorWithPadding(tokenizer)
dl = DataLoader(tokenized_sur_dataset, collate_fn=data_collator, batch_size=60, shuffle=False)

# %%
from tqdm.notebook import tqdm
model = model.to(device)
batch_len = []
labels = []
scores = []

model.eval()
with torch.no_grad():
    for b in tqdm(dl):
        batch_len.append(int(b["input_ids"].size()[0]))
        input_ids = b["input_ids"].to(device)
        attention_mask = b["attention_mask"].to(device)
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
#         outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        rank_score = list(outputs.logits)
        labels += list(b["pass_label"])
        scores += rank_score
        
#         print(pass_label.size())
#         mrr.append(cal_mrr(rank_score, pass_label))
#         if pred == None:
#             pred = rank_score
#             lab_p = pass_label
#         else:
#             pred = torch.cat((pred, rank_score), 0)
#             lab_p = torch.cat((lab_p, pass_label), 0)

#         for i in r_k.keys():
#             r_k[i].append(r_at_k(rank_score, pass_label, i))
# Out:
#   0%|          | 0/5598 [00:00<?, ?it/s]
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
scores = torch.tensor(scores)
labels = torch.tensor(labels[::150])

# %%
scores = scores.view(-1, 150)

# %%
scores.shape
# Out:
# torch.Size([2239, 150])

# %%
prediction = torch.argmax(scores, dim=1)

# %%
yesno = prediction == labels

# %%
print(f"accuracy: {yesno.sum()/yesno.shape[0]}")
# Out:
# accuracy: 0.9812416434288025

# %%
import torch
import torch.nn.functional as F

# %%
softmax_tensor = F.softmax(scores, dim=1)

# %%
softmax_tensor
# Out:
# tensor([[8.9893e-01, 1.8345e-06, 2.1319e-06,  ..., 2.0111e-06, 1.9681e-06,
#          1.9217e-06],
#         [9.2202e-01, 2.7869e-06, 3.0822e-06,  ..., 3.8197e-06, 2.9271e-06,
#          3.1819e-06],
#         [9.9045e-01, 1.7710e-06, 1.8109e-06,  ..., 2.9870e-06, 1.9244e-06,
#          2.2642e-06],
#         ...,
#         [5.5765e-05, 7.6165e-04, 4.5473e-05,  ..., 6.1609e-03, 9.4115e-04,
#          8.8583e-01],
#         [3.2148e-06, 1.1619e-05, 6.2872e-06,  ..., 2.1657e-05, 4.0117e-05,
#          9.9210e-01],
#         [8.3905e-06, 8.6799e-05, 2.1111e-05,  ..., 1.1388e-05, 6.9865e-05,
#          9.8238e-01]])

# %%
lk = 0
jk = []
for k, psd in enumerate(list(labels)):
    if psd != lk:
        jk.append(k)
        lk = psd

jk.append(k+1)

# %%
id2int = {v:k for k, v in int2id.items()}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix


# Calculate the confusion matrix
confusion = confusion_matrix(labels, prediction)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(40, 40))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[id2int[x] for x in range(150)], 
            yticklabels=[id2int[x] for x in range(150)])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
conf = torch.tensor(confusion)
conf = conf.argsort(dim=1, descending=True)

# %%
confusion
# Out:
# array([[15,  0,  0, ...,  0,  0,  0],
#        [ 0, 15,  0, ...,  0,  0,  0],
#        [ 0,  0, 15, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ..., 15,  0,  0],
#        [ 0,  0,  0, ...,  0, 15,  0],
#        [ 0,  0,  0, ...,  0,  0, 12]])

# %%
conf
# Out:
# tensor([[  0,  94, 111,  ...,  52,  53,  54],
#         [  1,  95, 112,  ...,  53,  54,  55],
#         [  2, 104,  95,  ...,  53,  54,  55],
#         ...,
#         [147, 103,  94,  ...,  53,  54,  55],
#         [148, 103,  94,  ...,  53,  54,  55],
#         [149,  76, 103,  ...,  53,  54,  55]])

# %%
confusion.shape
# Out:
# (150, 150)

# %%
import pickle

# Define the file name for saving the confusion matrix as a pickle
file_name = "confusion_matrix.pkl"

# Open the file in binary write mode
with open(file_name, "wb") as file:
    pickle.dump(conf, file)

print("Confusion Matrix saved as 'confusion_matrix.pkl'")
# Out:
# Confusion Matrix saved as 'confusion_matrix.pkl'

# %%
import pickle

# Load the confusion matrix from the pickle file
with open("confusion_matrix.pkl", "rb") as file:
    loaded_confusion = pickle.load(file)

# %%
jk
# Out:
# [15,
#  30,
#  45,
#  60,
#  75,
#  90,
#  105,
#  120,
#  135,
#  150,
#  165,
#  180,
#  195,
#  210,
#  225,
#  240,
#  255,
#  270,
#  285,
#  300,
#  315,
#  330,
#  345,
#  360,
#  375,
#  390,
#  405,
#  419,
#  434,
#  449,
#  464,
#  479,
#  494,
#  509,
#  524,
#  539,
#  554,
#  568,
#  583,
#  598,
#  613,
#  628,
#  643,
#  658,
#  673,
#  688,
#  703,
#  718,
#  733,
#  748,
#  763,
#  778,
#  793,
#  808,
#  823,
#  838,
#  853,
#  867,
#  882,
#  897,
#  912,
#  927,
#  941,
#  956,
#  971,
#  986,
#  1001,
#  1016,
#  1031,
#  1046,
#  1061,
#  1076,
#  1091,
#  1106,
#  1121,
#  1136,
#  1151,
#  1166,
#  1181,
#  1196,
#  1211,
#  1226,
#  1241,
#  1256,
#  1271,
#  1286,
#  1301,
#  1316,
#  1331,
#  1346,
#  1361,
#  1376,
#  1391,
#  1406,
#  1421,
#  1436,
#  1451,
#  1466,
#  1481,
#  1496,
#  1511,
#  1526,
#  1541,
#  1556,
#  1571,
#  1586,
#  1601,
#  1616,
#  1631,
#  1644,
#  1659,
#  1674,
#  1689,
#  1704,
#  1719,
#  1734,
#  1749,
#  1764,
#  1779,
#  1794,
#  1809,
#  1823,
#  1838,
#  1853,
#  1867,
#  1881,
#  1896,
#  1911,
#  1926,
#  1941,
#  1956,
#  1971,
#  1986,
#  2001,
#  2016,
#  2031,
#  2046,
#  2061,
#  2076,
#  2091,
#  2106,
#  2121,
#  2136,
#  2151,
#  2166,
#  2181,
#  2196,
#  2211,
#  2226,
#  2239]

# %%
prev = 0
out = []
for j in list(jk):
    sms = softmax_tensor[prev:j, :].mean(dim=0)
    out.append(list(sms))
    prev = j

# %%
out = torch.tensor(out)

# %%
confidence = out.argsort(dim=1, descending=True).tolist()

# %%
file_name = "confidence_matrix.pkl"

# Open the file in binary write mode
with open(file_name, "wb") as file:
    pickle.dump(confidence, file)

print("Confidence Matrix saved as 'confidence_matrix.pkl'")
# Out:
# Confidence Matrix saved as 'confidence_matrix.pkl'

# %%
cnfid = {}
for i, esd in enumerate(confidence):
    cnfid[i] = [id2int[x] for x in esd]

# %%
for i in range(20):
    print(f"{id2int[i]}: {cnfid[i][1:11]}")
# Out:
# accept reservations: ['restaurant reservation', 'confirm reservation', 'how busy', 'book hotel', 'cancel reservation', 'restaurant suggestion', 'schedule meeting', 'restaurant reviews', 'car rental', 'share location']
# account blocked: ['freeze account', 'balance', 'card declined', 'report fraud', 'damaged card', 'payday', 'rollover 401k', 'report lost card', 'expiration date', 'pin change']
# alarm: ['smart home', 'timer', 'reminder update', 'calendar update', 'calendar', 'reminder', 'schedule maintenance', 'make call', 'schedule meeting', 'sync device']
# application status: ['pto request status', 'flight status', 'new card', 'replacement card duration', 'expiration date', 'international visa', 'order status', 'w2', 'insurance', 'report lost card']
# apr: ['credit limit', 'interest rate', 'credit limit change', 'new card', 'transactions', 'taxes', 'credit score', 'improve credit score', 'expiration date', 'application status']
# are you a bot: ['who made you', 'how old are you', 'goodbye', 'thank you', 'what can i ask you', 'no', 'who do you work for', 'yes', 'maybe', 'change ai name']
# balance: ['bill balance', 'pay bill', 'payday', 'rewards balance', 'taxes', 'income', 'transactions', 'credit limit', 'pto balance', 'improve credit score']
# bill balance: ['min payment', 'balance', 'bill due', 'insurance', 'pay bill', 'taxes', 'income', 'payday', 'transactions', 'rewards balance']
# bill due: ['reminder', 'min payment', 'bill balance', 'reminder update', 'pay bill', 'expiration date', 'insurance', 'text', 'payday', 'calendar update']
# book flight: ['travel notification', 'flight status', 'lost luggage', 'book hotel', 'travel alert', 'carry on', 'uber', 'car rental', 'cancel reservation', 'pto request']
# book hotel: ['restaurant suggestion', 'car rental', 'book flight', 'travel suggestion', 'accept reservations', 'confirm reservation', 'pto request', 'cancel reservation', 'schedule meeting', 'uber']
# calculator: ['time', 'how old are you', 'mpg', 'timezone', 'date', 'where are you from', 'current location', 'definition', 'what can i ask you', 'yes']
# calendar: ['meeting schedule', 'reminder', 'reminder update', 'date', 'calendar update', 'flight status', 'todo list', 'schedule meeting', 'next holiday', 'time']
# calendar update: ['reminder update', 'cancel', 'cancel reservation', 'calendar', 'confirm reservation', 'update playlist', 'reminder', 'timer', 'schedule meeting', 'make call']
# calories: ['nutrition info', 'ingredients list', 'food last', 'how busy', 'cook time', 'recipe', 'ingredient substitution', 'shopping list update', 'calculator', 'measurement conversion']
# cancel: ['cancel reservation', 'reset settings', 'freeze account', 'calendar update', 'schedule meeting', 'confirm reservation', 'reminder', 'reminder update', 'repeat', 'text']
# cancel reservation: ['cancel', 'confirm reservation', 'calendar update', 'restaurant reservation', 'reminder', 'accept reservations', 'payday', 'schedule meeting', 'make call', 'calendar']
# car rental: ['book hotel', 'uber', 'travel notification', 'pto request', 'pay bill', 'insurance', 'mpg', 'book flight', 'schedule maintenance', 'directions']
# card declined: ['damaged card', 'improve credit score', 'report lost card', 'report fraud', 'account blocked', 'order', 'expiration date', 'replacement card duration', 'apr', 'oil change how']
# carry on: ['lost luggage', 'how busy', 'flight status', 'book flight', 'reminder', 'uber', 'international fees', 'reminder update', 'next holiday', 'travel alert']

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(out, annot=False, fmt='.2f', cmap='Blues', 
            xticklabels=[id2int[x] for x in range(150)], 
            yticklabels=[id2int[x] for x in range(150)])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
i = 56
print(f"{id2int[i]}: {cnfid[i][1:11]}")
# Out:
# ingredients list: ['recipe', 'nutrition info', 'cook time', 'calories', 'ingredient substitution', 'spelling', 'food last', 'fun fact', 'meal suggestion', 'what can i ask you']

# %%
# Out:
# {'accept reservations': ['accept reservations',
#   'restaurant reservation',
#   'confirm reservation',
#   'book hotel',
#   'cancel reservation',
#   'how busy',
#   'schedule meeting',
#   'restaurant reviews',
#   'restaurant suggestion',
#   'share location',
#   'routing',
#   'meeting schedule',
#   'current location',
#   'car rental',
#   'date',
#   'book flight',
#   'calendar',
#   'cancel',
#   'maybe',
#   'pto request',
#   'travel suggestion',
#   'fun fact',
#   'meal suggestion',
#   'expiration date',
#   'w2',
#   'insurance',
#   'credit score',
#   'uber',
#   'no',
#   'do you have pets',
#   'yes',
#   'application status',
#   'find phone',
#   'international visa',
#   'pto request status',
#   'directions',
#   'pto balance',
#   'reminder',
#   'spelling',
#   'travel notification',
#   'carry on',
#   'calendar update',
#   'recipe',
#   'translate',
#   'order checks',
#   'nutrition info',
#   'greeting',
#   'who do you work for',
#   'order',
#   'where are you from',
#   'flight status',
#   'order status',
#   'apr',
#   'lost luggage',
#   'next holiday',
#   'what are your hobbies',
#   'travel alert',
#   'vaccines',
#   'distance',
#   'taxes',
#   'definition',
#   'how old are you',
#   'what is your name',
#   'food last',
#   'weather',
#   'make call',
#   'interest rate',
#   'user name',
#   'calculator',
#   'what can i ask you',
#   'report fraud',
#   'payday',
#   'tell joke',
#   'card declined',
#   'bill due',
#   'replacement card duration',
#   'play music',
#   'goodbye',
#   'rewards balance',
#   'transactions',
#   'traffic',
#   'ingredients list',
#   'smart home',
#   'schedule maintenance',
#   'are you a bot',
#   'international fees',
#   'shopping list',
#   'gas type',
#   'account blocked',
#   'calories',
#   'what song',
#   'new card',
#   'gas',
#   'meaning of life',
#   'mpg',
#   'pay bill',
#   'pto used',
#   'income',
#   'redeem rewards',
#   'rollover 401k',
#   'last maintenance',
#   'cook time',
#   'shopping list update',
#   'min payment',
#   'time',
#   'text',
#   'thank you',
#   'credit limit',
#   'balance',
#   'bill balance',
#   'plug type',
#   'timezone',
#   'roll dice',
#   'who made you',
#   'spending history',
#   'credit limit change',
#   'ingredient substitution',
#   'todo list',
#   'insurance change',
#   'tire pressure',
#   'flip coin',
#   'report lost card',
#   'change accent',
#   'damaged card',
#   'improve credit score',
#   'reminder update',
#   'oil change when',
#   'change ai name',
#   'jump start',
#   'tire change',
#   'change user name',
#   'oil change how',
#   'repeat',
#   'sync device',
#   'direct deposit',
#   'freeze account',
#   'change speed',
#   'measurement conversion',
#   'transfer',
#   'todo list update',
#   'timer',
#   'exchange rate',
#   'whisper mode',
#   'pin change',
#   'alarm',
#   'reset settings',
#   'change language',
#   'next song',
#   'update playlist',
#   'change volume'],
#  'account blocked': ['account blocked',
#   'freeze account',
#   'card declined',
#   'report fraud',
#   'no',
#   'rollover 401k',
#   'balance',
#   'yes',
#   'fun fact',
#   'maybe',
#   'expiration date',
#   'thank you',
#   'routing',
#   'damaged card',
#   'spelling',
#   'are you a bot',
#   'tell joke',
#   'what are your hobbies',
#   'report lost card',
#   'who made you',
#   'payday',
#   'bill balance',
#   'flip coin',
#   'goodbye',
#   'lost luggage',
#   'last maintenance',
#   'transactions',
#   'pin change',
#   'definition',
#   'who do you work for',
#   'greeting',
#   'cancel',
#   'what can i ask you',
#   'transfer',
#   'apr',
#   'calculator',
#   'credit limit',
#   'meaning of life',
#   'improve credit score',
#   'application status',
#   'find phone',
#   'order checks',
#   'how old are you',
#   'direct deposit',
#   'pay bill',
#   'repeat',
#   'income',
#   'change ai name',
#   'taxes',
#   'where are you from',
#   'schedule maintenance',
#   'play music',
#   'smart home',
#   'interest rate',
#   'do you have pets',
#   'recipe',
#   'translate',
#   'book flight',
#   'w2',
#   'tire change',
#   'food last',
#   'change accent',
#   'roll dice',
#   'oil change when',
#   'rewards balance',
#   'reminder',
#   'min payment',
#   'oil change how',
#   'credit score',
#   'reset settings',
#   'insurance',
#   'jump start',
#   'travel notification',
#   'what is your name',
#   'redeem rewards',
#   'new card',
#   'spending history',
#   'uber',
#   'credit limit change',
#   'user name',
#   'calendar',
#   'tire pressure',
#   'text',
#   'cancel reservation',
#   'international fees',
#   'bill due',
#   'pto balance',
#   'ingredients list',
#   'what song',
#   'pto used',
#   'pto request',
#   'schedule meeting',
#   'sync device',
#   'change user name',
#   'shopping list update',
#   'next song',
#   'reminder update',
#   'order',
#   'gas',
#   'how busy',
#   'change speed',
#   'travel suggestion',
#   'whisper mode',
#   'international visa',
#   'replacement card duration',
#   'nutrition info',
#   'next holiday',
#   'share location',
#   'weather',
#   'date',
#   'flight status',
#   'todo list',
#   'mpg',
#   'todo list update',
#   'meal suggestion',
#   'insurance change',
#   'timer',
#   'vaccines',
#   'meeting schedule',
#   'traffic',
#   'current location',
#   'calories',
#   'shopping list',
#   'measurement conversion',
#   'plug type',
#   'make call',
#   'car rental',
#   'exchange rate',
#   'order status',
#   'time',
#   'travel alert',
#   'pto request status',
#   'update playlist',
#   'ingredient substitution',
#   'gas type',
#   'change volume',
#   'calendar update',
#   'cook time',
#   'timezone',
#   'restaurant suggestion',
#   'change language',
#   'directions',
#   'confirm reservation',
#   'restaurant reviews',
#   'book hotel',
#   'carry on',
#   'restaurant reservation',
#   'distance',
#   'alarm',
#   'accept reservations'],
#  'alarm': ['alarm',
#   'yes',
#   'thank you',
#   'no',
#   'smart home',
#   'reminder update',
#   'greeting',
#   'fun fact',
#   'maybe',
#   'goodbye',
#   'reminder',
#   'spelling',
#   'how old are you',
#   'cancel',
#   'next holiday',
#   'timer',
#   'tell joke',
#   'last maintenance',
#   'todo list',
#   'make call',
#   'where are you from',
#   'meaning of life',
#   'are you a bot',
#   'who do you work for',
#   'payday',
#   'what are your hobbies',
#   'do you have pets',
#   'calendar',
#   'calendar update',
#   'definition',
#   'improve credit score',
#   'credit score',
#   'who made you',
#   'cancel reservation',
#   'flip coin',
#   'freeze account',
#   'weather',
#   'translate',
#   'pto used',
#   'play music',
#   'lost luggage',
#   'calculator',
#   'repeat',
#   'whisper mode',
#   'text',
#   'find phone',
#   'damaged card',
#   'pay bill',
#   'pto request',
#   'what can i ask you',
#   'how busy',
#   'oil change when',
#   'order',
#   'travel suggestion',
#   'income',
#   'change speed',
#   'shopping list',
#   'change accent',
#   'report lost card',
#   'change user name',
#   'schedule maintenance',
#   'oil change how',
#   'timezone',
#   'rollover 401k',
#   'schedule meeting',
#   'report fraud',
#   'shopping list update',
#   'flight status',
#   'order status',
#   'tire change',
#   'min payment',
#   'jump start',
#   'travel notification',
#   'pto balance',
#   'ingredients list',
#   'what is your name',
#   'meal suggestion',
#   'todo list update',
#   'what song',
#   'carry on',
#   'recipe',
#   'meeting schedule',
#   'time',
#   'account blocked',
#   'directions',
#   'tire pressure',
#   'user name',
#   'date',
#   'card declined',
#   'change ai name',
#   'book flight',
#   'change volume',
#   'nutrition info',
#   'application status',
#   'roll dice',
#   'uber',
#   'traffic',
#   'insurance',
#   'expiration date',
#   'apr',
#   'spending history',
#   'measurement conversion',
#   'w2',
#   'balance',
#   'calories',
#   'gas',
#   'routing',
#   'sync device',
#   'credit limit',
#   'bill due',
#   'food last',
#   'ingredient substitution',
#   'travel alert',
#   'transactions',
#   'rewards balance',
#   'taxes',
#   'mpg',
#   'restaurant suggestion',
#   'international visa',
#   'gas type',
#   'car rental',
#   'pto request status',
#   'exchange rate',
#   'vaccines',
#   'distance',
#   'bill balance',
#   'cook time',
#   'current location',
#   'restaurant reviews',
#   'transfer',
#   'credit limit change',
#   'reset settings',
#   'share location',
#   'book hotel',
#   'interest rate',
#   'change language',
#   'update playlist',
#   'next song',
#   'insurance change',
#   'redeem rewards',
#   'confirm reservation',
#   'international fees',
#   'direct deposit',
#   'plug type',
#   'new card',
#   'accept reservations',
#   'replacement card duration',
#   'order checks',
#   'restaurant reservation',
#   'pin change'],
#  'application status': ['application status',
#   'pto request status',
#   'flight status',
#   'order status',
#   'new card',
#   'balance',
#   'international visa',
#   'apr',
#   'expiration date',
#   'maybe',
#   'date',
#   'yes',
#   'no',
#   'w2',
#   'credit score',
#   'who made you',
#   'credit limit',
#   'replacement card duration',
#   'spelling',
#   'interest rate',
#   'rewards balance',
#   'card declined',
#   'report lost card',
#   'greeting',
#   'reminder',
#   'travel notification',
#   'report fraud',
#   'calendar',
#   'damaged card',
#   'fun fact',
#   'rollover 401k',
#   'who do you work for',
#   'pto request',
#   'what can i ask you',
#   'thank you',
#   'how old are you',
#   'translate',
#   'credit limit change',
#   'redeem rewards',
#   'international fees',
#   'income',
#   'pay bill',
#   'transactions',
#   'taxes',
#   'where are you from',
#   'goodbye',
#   'what is your name',
#   'insurance',
#   'improve credit score',
#   'payday',
#   'schedule meeting',
#   'min payment',
#   'order checks',
#   'definition',
#   'last maintenance',
#   'bill due',
#   'pin change',
#   'meeting schedule',
#   'tell joke',
#   'are you a bot',
#   'account blocked',
#   'bill balance',
#   'calculator',
#   'cancel',
#   'freeze account',
#   'todo list',
#   'make call',
#   'meaning of life',
#   'do you have pets',
#   'pto balance',
#   'travel alert',
#   'text',
#   'change user name',
#   'share location',
#   'direct deposit',
#   'calendar update',
#   'routing',
#   'confirm reservation',
#   'user name',
#   'what are your hobbies',
#   'lost luggage',
#   'repeat',
#   'next holiday',
#   'vaccines',
#   'todo list update',
#   'find phone',
#   'reminder update',
#   'pto used',
#   'weather',
#   'smart home',
#   'order',
#   'shopping list update',
#   'current location',
#   'shopping list',
#   'cancel reservation',
#   'what song',
#   'schedule maintenance',
#   'book flight',
#   'spending history',
#   'time',
#   'uber',
#   'tire pressure',
#   'traffic',
#   'nutrition info',
#   'tire change',
#   'change accent',
#   'roll dice',
#   'carry on',
#   'jump start',
#   'mpg',
#   'transfer',
#   'how busy',
#   'oil change how',
#   'change ai name',
#   'sync device',
#   'timezone',
#   'directions',
#   'flip coin',
#   'oil change when',
#   'car rental',
#   'timer',
#   'recipe',
#   'gas',
#   'insurance change',
#   'reset settings',
#   'play music',
#   'travel suggestion',
#   'calories',
#   'food last',
#   'change language',
#   'whisper mode',
#   'plug type',
#   'ingredients list',
#   'measurement conversion',
#   'gas type',
#   'change speed',
#   'distance',
#   'restaurant suggestion',
#   'book hotel',
#   'alarm',
#   'exchange rate',
#   'accept reservations',
#   'meal suggestion',
#   'restaurant reviews',
#   'cook time',
#   'restaurant reservation',
#   'update playlist',
#   'next song',
#   'change volume',
#   'ingredient substitution'],
#  'apr': ['apr',
#   'credit limit',
#   'credit limit change',
#   'transactions',
#   'routing',
#   'interest rate',
#   'credit score',
#   'rewards balance',
#   'taxes',
#   'new card',
#   'definition',
#   'application status',
#   'improve credit score',
#   'yes',
#   'min payment',
#   'rollover 401k',
#   'balance',
#   'expiration date',
#   'bill balance',
#   'international fees',
#   'what can i ask you',
#   'spelling',
#   'fun fact',
#   'maybe',
#   'report fraud',
#   'no',
#   'pay bill',
#   'insurance',
#   'translate',
#   'calculator',
#   'greeting',
#   'who do you work for',
#   'meaning of life',
#   'redeem rewards',
#   'report lost card',
#   'card declined',
#   'how old are you',
#   'tell joke',
#   'bill due',
#   'do you have pets',
#   'are you a bot',
#   'damaged card',
#   'where are you from',
#   'who made you',
#   'what are your hobbies',
#   'last maintenance',
#   'car rental',
#   'income',
#   'what is your name',
#   'what song',
#   'pin change',
#   'freeze account',
#   'payday',
#   'thank you',
#   'mpg',
#   'flip coin',
#   'nutrition info',
#   'make call',
#   'pto balance',
#   'reminder',
#   'recipe',
#   'goodbye',
#   'replacement card duration',
#   'direct deposit',
#   'find phone',
#   'share location',
#   'date',
#   'next holiday',
#   'spending history',
#   'user name',
#   'repeat',
#   'w2',
#   'calendar',
#   'transfer',
#   'insurance change',
#   'exchange rate',
#   'todo list',
#   'travel notification',
#   'pto request',
#   'shopping list',
#   'schedule meeting',
#   'cancel',
#   'play music',
#   'account blocked',
#   'pto used',
#   'cancel reservation',
#   'international visa',
#   'tire change',
#   'lost luggage',
#   'ingredients list',
#   'oil change how',
#   'restaurant reviews',
#   'order',
#   'travel suggestion',
#   'text',
#   'book hotel',
#   'gas type',
#   'uber',
#   'smart home',
#   'current location',
#   'oil change when',
#   'roll dice',
#   'how busy',
#   'weather',
#   'schedule maintenance',
#   'restaurant suggestion',
#   'change ai name',
#   'meeting schedule',
#   'change accent',
#   'order status',
#   'reminder update',
#   'time',
#   'book flight',
#   'change speed',
#   'timezone',
#   'tire pressure',
#   'meal suggestion',
#   'order checks',
#   'travel alert',
#   'pto request status',
#   'food last',
#   'gas',
#   'jump start',
#   'directions',
#   'calories',
#   'change user name',
#   'plug type',
#   'flight status',
#   'confirm reservation',
#   'vaccines',
#   'distance',
#   'shopping list update',
#   'measurement conversion',
#   'carry on',
#   'calendar update',
#   'next song',
#   'traffic',
#   'sync device',
#   'ingredient substitution',
#   'timer',
#   'update playlist',
#   'todo list update',
#   'reset settings',
#   'change language',
#   'cook time',
#   'restaurant reservation',
#   'whisper mode',
#   'alarm',
#   'accept reservations',
#   'change volume'],
#  'are you a bot': ['are you a bot',
#   'who made you',
#   'how old are you',
#   'thank you',
#   'yes',
#   'goodbye',
#   'no',
#   'what can i ask you',
#   'where are you from',
#   'fun fact',
#   'what are your hobbies',
#   'meaning of life',
#   'do you have pets',
#   'definition',
#   'spelling',
#   'greeting',
#   'who do you work for',
#   'maybe',
#   'what is your name',
#   'tell joke',
#   'user name',
#   'translate',
#   'last maintenance',
#   'calculator',
#   'make call',
#   'change accent',
#   'change speed',
#   'report fraud',
#   'play music',
#   'flip coin',
#   'repeat',
#   'roll dice',
#   'text',
#   'whisper mode',
#   'lost luggage',
#   'recipe',
#   'change ai name',
#   'rollover 401k',
#   'credit score',
#   'report lost card',
#   'find phone',
#   'cancel',
#   'damaged card',
#   'reminder',
#   'what song',
#   'oil change how',
#   'income',
#   'apr',
#   'improve credit score',
#   'payday',
#   'smart home',
#   'share location',
#   'change user name',
#   'taxes',
#   'balance',
#   'nutrition info',
#   'application status',
#   'account blocked',
#   'jump start',
#   'travel suggestion',
#   'ingredients list',
#   'pay bill',
#   'min payment',
#   'freeze account',
#   'next holiday',
#   'oil change when',
#   'card declined',
#   'spending history',
#   'tire pressure',
#   'direct deposit',
#   'todo list',
#   'credit limit',
#   'cancel reservation',
#   'tire change',
#   'pto request',
#   'mpg',
#   'meal suggestion',
#   'transactions',
#   'routing',
#   'shopping list',
#   'date',
#   'w2',
#   'travel notification',
#   'sync device',
#   'current location',
#   'schedule meeting',
#   'calories',
#   'pto used',
#   'reset settings',
#   'calendar',
#   'weather',
#   'order',
#   'reminder update',
#   'schedule maintenance',
#   'pto balance',
#   'todo list update',
#   'timezone',
#   'transfer',
#   'book flight',
#   'change volume',
#   'food last',
#   'next song',
#   'flight status',
#   'interest rate',
#   'uber',
#   'insurance',
#   'shopping list update',
#   'update playlist',
#   'gas',
#   'international visa',
#   'bill balance',
#   'vaccines',
#   'measurement conversion',
#   'expiration date',
#   'meeting schedule',
#   'order status',
#   'how busy',
#   'restaurant suggestion',
#   'pto request status',
#   'alarm',
#   'traffic',
#   'directions',
#   'car rental',
#   'rewards balance',
#   'time',
#   'travel alert',
#   'gas type',
#   'new card',
#   'redeem rewards',
#   'timer',
#   'calendar update',
#   'restaurant reviews',
#   'replacement card duration',
#   'bill due',
#   'credit limit change',
#   'international fees',
#   'change language',
#   'insurance change',
#   'pin change',
#   'distance',
#   'exchange rate',
#   'order checks',
#   'cook time',
#   'plug type',
#   'ingredient substitution',
#   'confirm reservation',
#   'book hotel',
#   'restaurant reservation',
#   'carry on',
#   'accept reservations'],
#  'balance': ['balance',
#   'bill balance',
#   'income',
#   'application status',
#   'rewards balance',
#   'rollover 401k',
#   'transactions',
#   'fun fact',
#   'pto balance',
#   'transfer',
#   'yes',
#   'taxes',
#   'greeting',
#   'pay bill',
#   'how old are you',
#   'thank you',
#   'credit limit',
#   'payday',
#   'improve credit score',
#   'what can i ask you',
#   'definition',
#   'spending history',
#   'maybe',
#   'meaning of life',
#   'apr',
#   'min payment',
#   'no',
#   'calculator',
#   'who do you work for',
#   'spelling',
#   'credit score',
#   'where are you from',
#   'pin change',
#   'flight status',
#   'what are your hobbies',
#   'interest rate',
#   'do you have pets',
#   'travel notification',
#   'insurance',
#   'nutrition info',
#   'calendar',
#   'tell joke',
#   'freeze account',
#   'report fraud',
#   'translate',
#   'reminder',
#   'expiration date',
#   'last maintenance',
#   'date',
#   'routing',
#   'who made you',
#   'goodbye',
#   'new card',
#   'order checks',
#   'pto request status',
#   'damaged card',
#   'w2',
#   'share location',
#   'are you a bot',
#   'book flight',
#   'bill due',
#   'pto request',
#   'what is your name',
#   'direct deposit',
#   'account blocked',
#   'cancel',
#   'schedule meeting',
#   'next holiday',
#   'recipe',
#   'order status',
#   'todo list update',
#   'reminder update',
#   'todo list',
#   'what song',
#   'calendar update',
#   'redeem rewards',
#   'text',
#   'report lost card',
#   'repeat',
#   'shopping list',
#   'pto used',
#   'make call',
#   'flip coin',
#   'card declined',
#   'car rental',
#   'user name',
#   'meeting schedule',
#   'ingredients list',
#   'international fees',
#   'oil change how',
#   'play music',
#   'order',
#   'change ai name',
#   'change accent',
#   'change user name',
#   'schedule maintenance',
#   'insurance change',
#   'jump start',
#   'lost luggage',
#   'smart home',
#   'credit limit change',
#   'shopping list update',
#   'mpg',
#   'roll dice',
#   'travel suggestion',
#   'gas',
#   'how busy',
#   'weather',
#   'international visa',
#   'calories',
#   'travel alert',
#   'vaccines',
#   'cancel reservation',
#   'time',
#   'confirm reservation',
#   'meal suggestion',
#   'tire change',
#   'replacement card duration',
#   'tire pressure',
#   'restaurant suggestion',
#   'directions',
#   'find phone',
#   'book hotel',
#   'uber',
#   'oil change when',
#   'next song',
#   'food last',
#   'timezone',
#   'restaurant reviews',
#   'traffic',
#   'exchange rate',
#   'current location',
#   'reset settings',
#   'measurement conversion',
#   'ingredient substitution',
#   'gas type',
#   'whisper mode',
#   'plug type',
#   'timer',
#   'carry on',
#   'change speed',
#   'update playlist',
#   'sync device',
#   'distance',
#   'cook time',
#   'alarm',
#   'restaurant reservation',
#   'change volume',
#   'accept reservations',
#   'change language'],
#  'bill balance': ['bill balance',
#   'min payment',
#   'balance',
#   'rewards balance',
#   'income',
#   'bill due',
#   'insurance',
#   'spending history',
#   'transactions',
#   'taxes',
#   'credit limit',
#   'calendar',
#   'pay bill',
#   'pto balance',
#   'routing',
#   'apr',
#   'payday',
#   'reminder',
#   'calculator',
#   'report fraud',
#   'rollover 401k',
#   'interest rate',
#   'international fees',
#   'who do you work for',
#   'report lost card',
#   'freeze account',
#   'travel notification',
#   'fun fact',
#   'yes',
#   'spelling',
#   'how old are you',
#   'todo list',
#   'no',
#   'maybe',
#   'greeting',
#   'order checks',
#   'do you have pets',
#   'application status',
#   'w2',
#   'date',
#   'transfer',
#   'thank you',
#   'expiration date',
#   'direct deposit',
#   'what can i ask you',
#   'definition',
#   'translate',
#   'pto used',
#   'last maintenance',
#   'where are you from',
#   'meeting schedule',
#   'account blocked',
#   'credit score',
#   'what are your hobbies',
#   'todo list update',
#   'pto request status',
#   'tell joke',
#   'pin change',
#   'nutrition info',
#   'redeem rewards',
#   'meaning of life',
#   'next holiday',
#   'credit limit change',
#   'new card',
#   'insurance change',
#   'shopping list',
#   'share location',
#   'order status',
#   'pto request',
#   'goodbye',
#   'what is your name',
#   'are you a bot',
#   'text',
#   'make call',
#   'damaged card',
#   'mpg',
#   'what song',
#   'how busy',
#   'improve credit score',
#   'who made you',
#   'uber',
#   'gas',
#   'car rental',
#   'tire change',
#   'time',
#   'order',
#   'schedule meeting',
#   'card declined',
#   'international visa',
#   'vaccines',
#   'lost luggage',
#   'flight status',
#   'schedule maintenance',
#   'weather',
#   'calories',
#   'ingredients list',
#   'reminder update',
#   'gas type',
#   'travel suggestion',
#   'confirm reservation',
#   'recipe',
#   'carry on',
#   'user name',
#   'replacement card duration',
#   'find phone',
#   'oil change how',
#   'cancel',
#   'calendar update',
#   'food last',
#   'shopping list update',
#   'cancel reservation',
#   'repeat',
#   'directions',
#   'exchange rate',
#   'tire pressure',
#   'timezone',
#   'jump start',
#   'oil change when',
#   'flip coin',
#   'book hotel',
#   'traffic',
#   'book flight',
#   'play music',
#   'roll dice',
#   'travel alert',
#   'current location',
#   'plug type',
#   'change user name',
#   'smart home',
#   'distance',
#   'restaurant suggestion',
#   'meal suggestion',
#   'measurement conversion',
#   'cook time',
#   'restaurant reviews',
#   'change accent',
#   'sync device',
#   'restaurant reservation',
#   'ingredient substitution',
#   'change speed',
#   'change ai name',
#   'reset settings',
#   'timer',
#   'accept reservations',
#   'whisper mode',
#   'change volume',
#   'alarm',
#   'next song',
#   'update playlist',
#   'change language'],
#  'bill due': ['bill due',
#   'min payment',
#   'bill balance',
#   'pay bill',
#   'expiration date',
#   'balance',
#   'credit limit',
#   'payday',
#   'damaged card',
#   'apr',
#   'taxes',
#   'credit limit change',
#   'reminder update',
#   'card declined',
#   'international fees',
#   'reminder',
#   'redeem rewards',
#   'calendar',
#   'new card',
#   'date',
#   'find phone',
#   'transactions',
#   'report lost card',
#   'rewards balance',
#   'maybe',
#   'spelling',
#   'improve credit score',
#   'report fraud',
#   'fun fact',
#   'routing',
#   'no',
#   'yes',
#   'how old are you',
#   'insurance',
#   'application status',
#   'interest rate',
#   'rollover 401k',
#   'next holiday',
#   'credit score',
#   'replacement card duration',
#   'pto balance',
#   'who do you work for',
#   'calculator',
#   'w2',
#   'transfer',
#   'definition',
#   'translate',
#   'direct deposit',
#   'text',
#   'what can i ask you',
#   'pin change',
#   'greeting',
#   'freeze account',
#   'income',
#   'meeting schedule',
#   'time',
#   'todo list',
#   'last maintenance',
#   'spending history',
#   'travel notification',
#   'meaning of life',
#   'what are your hobbies',
#   'how busy',
#   'order status',
#   'pto request',
#   'do you have pets',
#   'pto request status',
#   'share location',
#   'thank you',
#   'account blocked',
#   'where are you from',
#   'tell joke',
#   'smart home',
#   'pto used',
#   'goodbye',
#   'make call',
#   'international visa',
#   'carry on',
#   'calendar update',
#   'cancel reservation',
#   'schedule meeting',
#   'lost luggage',
#   'are you a bot',
#   'cancel',
#   'shopping list',
#   'flight status',
#   'travel suggestion',
#   'user name',
#   'flip coin',
#   'what is your name',
#   'weather',
#   'timezone',
#   'travel alert',
#   'current location',
#   'order',
#   'order checks',
#   'what song',
#   'timer',
#   'confirm reservation',
#   'uber',
#   'traffic',
#   'recipe',
#   'schedule maintenance',
#   'food last',
#   'vaccines',
#   'todo list update',
#   'repeat',
#   'directions',
#   'tire change',
#   'car rental',
#   'insurance change',
#   'tire pressure',
#   'sync device',
#   'ingredients list',
#   'nutrition info',
#   'oil change how',
#   'book flight',
#   'gas',
#   'book hotel',
#   'oil change when',
#   'alarm',
#   'mpg',
#   'jump start',
#   'restaurant suggestion',
#   'exchange rate',
#   'gas type',
#   'distance',
#   'who made you',
#   'plug type',
#   'play music',
#   'roll dice',
#   'restaurant reviews',
#   'calories',
#   'shopping list update',
#   'change user name',
#   'measurement conversion',
#   'accept reservations',
#   'change speed',
#   'change accent',
#   'cook time',
#   'restaurant reservation',
#   'meal suggestion',
#   'ingredient substitution',
#   'reset settings',
#   'change ai name',
#   'whisper mode',
#   'next song',
#   'change language',
#   'change volume',
#   'update playlist'],
#  'book flight': ['book flight',
#   'spelling',
#   'uber',
#   'fun fact',
#   'maybe',
#   'distance',
#   'carry on',
#   'yes',
#   'no',
#   'flight status',
#   'book hotel',
#   'travel notification',
#   'greeting',
#   'where are you from',
#   'lost luggage',
#   'thank you',
#   'tell joke',
#   'meaning of life',
#   'pto request',
#   'car rental',
#   'how old are you',
#   'travel alert',
#   'cancel reservation',
#   'travel suggestion',
#   'who do you work for',
#   'calculator',
#   'are you a bot',
#   'share location',
#   'who made you',
#   'international visa',
#   'definition',
#   'translate',
#   'directions',
#   'what are your hobbies',
#   'do you have pets',
#   'goodbye',
#   'order',
#   'what can i ask you',
#   'cancel',
#   'roll dice',
#   'vaccines',
#   'weather',
#   'flip coin',
#   'reminder',
#   'text',
#   'calendar',
#   'income',
#   'next holiday',
#   'date',
#   'last maintenance',
#   'what is your name',
#   'improve credit score',
#   'play music',
#   'insurance',
#   'freeze account',
#   'rollover 401k',
#   'report fraud',
#   'repeat',
#   'pto request status',
#   'meal suggestion',
#   'damaged card',
#   'reminder update',
#   'pto used',
#   'oil change how',
#   'redeem rewards',
#   'pto balance',
#   'make call',
#   'report lost card',
#   'traffic',
#   'card declined',
#   'taxes',
#   'recipe',
#   'nutrition info',
#   'spending history',
#   'pay bill',
#   'current location',
#   'min payment',
#   'account blocked',
#   'credit score',
#   'direct deposit',
#   'what song',
#   'find phone',
#   'schedule meeting',
#   'payday',
#   'mpg',
#   'ingredients list',
#   'apr',
#   'time',
#   'confirm reservation',
#   'credit limit',
#   'calories',
#   'balance',
#   'change accent',
#   'interest rate',
#   'timezone',
#   'change ai name',
#   'calendar update',
#   'tire pressure',
#   'tire change',
#   'oil change when',
#   'user name',
#   'shopping list',
#   'todo list',
#   'todo list update',
#   'schedule maintenance',
#   'gas',
#   'routing',
#   'insurance change',
#   'measurement conversion',
#   'expiration date',
#   'jump start',
#   'meeting schedule',
#   'w2',
#   'application status',
#   'bill balance',
#   'how busy',
#   'international fees',
#   'credit limit change',
#   'restaurant reservation',
#   'food last',
#   'order status',
#   'change user name',
#   'restaurant suggestion',
#   'update playlist',
#   'rewards balance',
#   'restaurant reviews',
#   'cook time',
#   'change speed',
#   'timer',
#   'ingredient substitution',
#   'bill due',
#   'exchange rate',
#   'gas type',
#   'transactions',
#   'new card',
#   'sync device',
#   'next song',
#   'shopping list update',
#   'replacement card duration',
#   'whisper mode',
#   'reset settings',
#   'alarm',
#   'plug type',
#   'accept reservations',
#   'change language',
#   'smart home',
#   'pin change',
#   'transfer',
#   'change volume',
#   'order checks'],
#  'book hotel': ['book hotel',
#   'restaurant suggestion',
#   'pto request',
#   'restaurant reservation',
#   'accept reservations',
#   'spelling',
#   'schedule meeting',
#   'book flight',
#   'yes',
#   'uber',
#   'travel suggestion',
#   'share location',
#   'maybe',
#   'car rental',
#   'no',
#   'restaurant reviews',
#   'fun fact',
#   'cancel reservation',
#   'meal suggestion',
#   'where are you from',
#   'confirm reservation',
#   'thank you',
#   'what are your hobbies',
#   'who do you work for',
#   'greeting',
#   'what can i ask you',
#   'tell joke',
#   'definition',
#   'directions',
#   'goodbye',
#   'translate',
#   'what is your name',
#   'lost luggage',
#   'current location',
#   'meaning of life',
#   'do you have pets',
#   'cancel',
#   'calculator',
#   'make call',
#   'date',
#   'reminder',
#   'insurance',
#   'are you a bot',
#   'how old are you',
#   'calendar update',
#   'weather',
#   'travel notification',
#   'time',
#   'how busy',
#   'next holiday',
#   'order',
#   'play music',
#   'pay bill',
#   'user name',
#   'calendar',
#   'find phone',
#   'travel alert',
#   'pto request status',
#   'taxes',
#   'last maintenance',
#   'change user name',
#   'text',
#   'smart home',
#   'credit score',
#   'report fraud',
#   'pto balance',
#   'recipe',
#   'flip coin',
#   'international visa',
#   'change ai name',
#   'timezone',
#   'distance',
#   'income',
#   'nutrition info',
#   'w2',
#   'change accent',
#   'repeat',
#   'shopping list',
#   'who made you',
#   'new card',
#   'meeting schedule',
#   'what song',
#   'traffic',
#   'improve credit score',
#   'min payment',
#   'rollover 401k',
#   'flight status',
#   'apr',
#   'insurance change',
#   'reminder update',
#   'todo list update',
#   'pto used',
#   'spending history',
#   'balance',
#   'schedule maintenance',
#   'direct deposit',
#   'carry on',
#   'roll dice',
#   'interest rate',
#   'shopping list update',
#   'application status',
#   'vaccines',
#   'card declined',
#   'calories',
#   'credit limit',
#   'payday',
#   'todo list',
#   'order checks',
#   'freeze account',
#   'account blocked',
#   'measurement conversion',
#   'damaged card',
#   'whisper mode',
#   'jump start',
#   'plug type',
#   'oil change how',
#   'mpg',
#   'ingredients list',
#   'report lost card',
#   'oil change when',
#   'expiration date',
#   'timer',
#   'routing',
#   'gas',
#   'exchange rate',
#   'redeem rewards',
#   'change speed',
#   'international fees',
#   'tire pressure',
#   'food last',
#   'order status',
#   'tire change',
#   'bill balance',
#   'sync device',
#   'credit limit change',
#   'gas type',
#   'transactions',
#   'change language',
#   'update playlist',
#   'alarm',
#   'rewards balance',
#   'change volume',
#   'reset settings',
#   'bill due',
#   'next song',
#   'transfer',
#   'cook time',
#   'pin change',
#   'ingredient substitution',
#   'replacement card duration'],
#  'calculator': ['calculator',
#   'spelling',
#   'how old are you',
#   'fun fact',
#   'where are you from',
#   'definition',
#   'what can i ask you',
#   'meaning of life',
#   'mpg',
#   'greeting',
#   'yes',
#   'do you have pets',
#   'balance',
#   'who made you',
#   'maybe',
#   'what are your hobbies',
#   'thank you',
#   'tell joke',
#   'income',
#   'no',
#   'current location',
#   'translate',
#   'nutrition info',
#   'taxes',
#   'what is your name',
#   'are you a bot',
#   'pto balance',
#   'time',
#   'timezone',
#   'spending history',
#   'who do you work for',
#   'date',
#   'credit score',
#   'last maintenance',
#   'goodbye',
#   'insurance',
#   'jump start',
#   'gas',
#   'rollover 401k',
#   'routing',
#   'weather',
#   'measurement conversion',
#   'apr',
#   'min payment',
#   'ingredients list',
#   'user name',
#   'travel suggestion',
#   'tire change',
#   'tire pressure',
#   'next holiday',
#   'payday',
#   'pto used',
#   'distance',
#   'interest rate',
#   'what song',
#   'improve credit score',
#   'directions',
#   'flip coin',
#   'reminder',
#   'traffic',
#   'calories',
#   'bill balance',
#   'roll dice',
#   'gas type',
#   'calendar',
#   'w2',
#   'todo list',
#   'recipe',
#   'expiration date',
#   'exchange rate',
#   'oil change how',
#   'car rental',
#   'vaccines',
#   'pto request',
#   'international visa',
#   'share location',
#   'how busy',
#   'find phone',
#   'credit limit',
#   'shopping list',
#   'pay bill',
#   'oil change when',
#   'report fraud',
#   'travel alert',
#   'uber',
#   'bill due',
#   'new card',
#   'schedule meeting',
#   'damaged card',
#   'rewards balance',
#   'carry on',
#   'schedule maintenance',
#   'report lost card',
#   'application status',
#   'lost luggage',
#   'repeat',
#   'international fees',
#   'transactions',
#   'plug type',
#   'travel notification',
#   'smart home',
#   'direct deposit',
#   'order status',
#   'order',
#   'flight status',
#   'freeze account',
#   'replacement card duration',
#   'redeem rewards',
#   'cancel',
#   'meeting schedule',
#   'pto request status',
#   'account blocked',
#   'insurance change',
#   'book flight',
#   'food last',
#   'play music',
#   'text',
#   'card declined',
#   'reminder update',
#   'credit limit change',
#   'book hotel',
#   'change ai name',
#   'make call',
#   'change speed',
#   'todo list update',
#   'cook time',
#   'shopping list update',
#   'change accent',
#   'change user name',
#   'meal suggestion',
#   'restaurant reviews',
#   'timer',
#   'restaurant suggestion',
#   'sync device',
#   'order checks',
#   'ingredient substitution',
#   'transfer',
#   'cancel reservation',
#   'calendar update',
#   'next song',
#   'alarm',
#   'confirm reservation',
#   'reset settings',
#   'change volume',
#   'pin change',
#   'whisper mode',
#   'update playlist',
#   'restaurant reservation',
#   'change language',
#   'accept reservations'],
#  'calendar': ['calendar',
#   'meeting schedule',
#   'date',
#   'calendar update',
#   'reminder update',
#   'schedule meeting',
#   'flight status',
#   'reminder',
#   'todo list',
#   'spelling',
#   'alarm',
#   'time',
#   'no',
#   'maybe',
#   'yes',
#   'next holiday',
#   'timer',
#   'travel notification',
#   'pto balance',
#   'fun fact',
#   'balance',
#   'last maintenance',
#   'tell joke',
#   'what are your hobbies',
#   'calculator',
#   'timezone',
#   'thank you',
#   'greeting',
#   'share location',
#   'pto request',
#   'what is your name',
#   'make call',
#   'book flight',
#   'goodbye',
#   'how old are you',
#   'definition',
#   'confirm reservation',
#   'weather',
#   'translate',
#   'meaning of life',
#   'todo list update',
#   'distance',
#   'who do you work for',
#   'cancel',
#   'bill due',
#   'do you have pets',
#   'income',
#   'text',
#   'smart home',
#   'what can i ask you',
#   'pto used',
#   'current location',
#   'payday',
#   'schedule maintenance',
#   'where are you from',
#   'pto request status',
#   'cancel reservation',
#   'credit limit',
#   'play music',
#   'change accent',
#   'expiration date',
#   'are you a bot',
#   'insurance',
#   'carry on',
#   'vaccines',
#   'bill balance',
#   'update playlist',
#   'repeat',
#   'travel alert',
#   'taxes',
#   'credit score',
#   'min payment',
#   'rollover 401k',
#   'shopping list update',
#   'flip coin',
#   'nutrition info',
#   'travel suggestion',
#   'pay bill',
#   'roll dice',
#   'user name',
#   'order',
#   'change user name',
#   'recipe',
#   'w2',
#   'tire pressure',
#   'what song',
#   'directions',
#   'shopping list',
#   'lost luggage',
#   'spending history',
#   'uber',
#   'how busy',
#   'improve credit score',
#   'oil change when',
#   'insurance change',
#   'apr',
#   'change ai name',
#   'direct deposit',
#   'meal suggestion',
#   'change speed',
#   'calories',
#   'interest rate',
#   'whisper mode',
#   'food last',
#   'who made you',
#   'freeze account',
#   'measurement conversion',
#   'tire change',
#   'ingredients list',
#   'sync device',
#   'order status',
#   'find phone',
#   'international visa',
#   'car rental',
#   'oil change how',
#   'application status',
#   'traffic',
#   'damaged card',
#   'mpg',
#   'gas',
#   'card declined',
#   'cook time',
#   'jump start',
#   'accept reservations',
#   'account blocked',
#   'new card',
#   'routing',
#   'restaurant suggestion',
#   'transactions',
#   'plug type',
#   'book hotel',
#   'report lost card',
#   'gas type',
#   'report fraud',
#   'replacement card duration',
#   'restaurant reservation',
#   'next song',
#   'rewards balance',
#   'credit limit change',
#   'redeem rewards',
#   'ingredient substitution',
#   'transfer',
#   'exchange rate',
#   'reset settings',
#   'restaurant reviews',
#   'change language',
#   'change volume',
#   'international fees',
#   'order checks',
#   'pin change'],
#  'calendar update': ['calendar update',
#   'reminder update',
#   'cancel reservation',
#   'cancel',
#   'confirm reservation',
#   'timer',
#   'calendar',
#   'schedule meeting',
#   'meeting schedule',
#   'alarm',
#   'reminder',
#   'restaurant reservation',
#   'make call',
#   'todo list update',
#   'transfer',
#   'pto request status',
#   'pto request',
#   'date',
#   'goodbye',
#   'no',
#   'maybe',
#   'greeting',
#   'text',
#   'yes',
#   'spelling',
#   'reset settings',
#   'tell joke',
#   'thank you',
#   'how old are you',
#   'last maintenance',
#   'schedule maintenance',
#   'pay bill',
#   'where are you from',
#   'are you a bot',
#   'next holiday',
#   'play music',
#   'what are your hobbies',
#   'fun fact',
#   'who do you work for',
#   'share location',
#   'meaning of life',
#   'change accent',
#   'repeat',
#   'update playlist',
#   'todo list',
#   'damaged card',
#   'who made you',
#   'travel notification',
#   'freeze account',
#   'roll dice',
#   'card declined',
#   'lost luggage',
#   'what is your name',
#   'change user name',
#   'what can i ask you',
#   'do you have pets',
#   'calculator',
#   'find phone',
#   'definition',
#   'meal suggestion',
#   'uber',
#   'travel suggestion',
#   'book flight',
#   'change speed',
#   'recipe',
#   'user name',
#   'income',
#   'account blocked',
#   'accept reservations',
#   'translate',
#   'flight status',
#   'ingredients list',
#   'smart home',
#   'flip coin',
#   'change ai name',
#   'payday',
#   'balance',
#   'whisper mode',
#   'expiration date',
#   'report lost card',
#   'order',
#   'oil change when',
#   'rollover 401k',
#   'pto used',
#   'what song',
#   'min payment',
#   'improve credit score',
#   'weather',
#   'report fraud',
#   'oil change how',
#   'tire change',
#   'current location',
#   'pto balance',
#   'application status',
#   'w2',
#   'vaccines',
#   'order status',
#   'calories',
#   'credit limit',
#   'time',
#   'shopping list update',
#   'credit score',
#   'nutrition info',
#   'food last',
#   'shopping list',
#   'how busy',
#   'sync device',
#   'jump start',
#   'book hotel',
#   'transactions',
#   'directions',
#   'restaurant suggestion',
#   'tire pressure',
#   'credit limit change',
#   'direct deposit',
#   'taxes',
#   'international visa',
#   'pin change',
#   'insurance change',
#   'rewards balance',
#   'measurement conversion',
#   'routing',
#   'car rental',
#   'distance',
#   'bill balance',
#   'timezone',
#   'bill due',
#   'cook time',
#   'change language',
#   'apr',
#   'mpg',
#   'traffic',
#   'spending history',
#   'new card',
#   'travel alert',
#   'exchange rate',
#   'replacement card duration',
#   'redeem rewards',
#   'insurance',
#   'order checks',
#   'change volume',
#   'carry on',
#   'restaurant reviews',
#   'gas',
#   'ingredient substitution',
#   'international fees',
#   'interest rate',
#   'next song',
#   'plug type',
#   'gas type'],
#  'calories': ['calories',
#   'nutrition info',
#   'ingredients list',
#   'cook time',
#   'measurement conversion',
#   'food last',
#   'recipe',
#   'calculator',
#   'fun fact',
#   'ingredient substitution',
#   'definition',
#   'how old are you',
#   'spelling',
#   'yes',
#   'do you have pets',
#   'no',
#   'restaurant reviews',
#   'what are your hobbies',
#   'maybe',
#   'mpg',
#   'meal suggestion',
#   'meaning of life',
#   'income',
#   'tell joke',
#   'where are you from',
#   'how busy',
#   'shopping list update',
#   'spending history',
#   'greeting',
#   'what can i ask you',
#   'thank you',
#   'shopping list',
#   'who do you work for',
#   'restaurant suggestion',
#   'translate',
#   'are you a bot',
#   'pto used',
#   'reminder',
#   'what is your name',
#   'insurance',
#   'goodbye',
#   'carry on',
#   'gas',
#   'gas type',
#   'credit score',
#   'last maintenance',
#   'balance',
#   'taxes',
#   'travel suggestion',
#   'flip coin',
#   'weather',
#   'share location',
#   'pto balance',
#   'date',
#   'vaccines',
#   'next holiday',
#   'lost luggage',
#   'current location',
#   'time',
#   'calendar update',
#   'todo list',
#   'reminder update',
#   'user name',
#   'min payment',
#   'apr',
#   'calendar',
#   'improve credit score',
#   'who made you',
#   'order',
#   'oil change how',
#   'timezone',
#   'cancel',
#   'bill balance',
#   'credit limit',
#   'tire pressure',
#   'todo list update',
#   'order status',
#   'directions',
#   'text',
#   'distance',
#   'accept reservations',
#   'exchange rate',
#   'rollover 401k',
#   'jump start',
#   'smart home',
#   'expiration date',
#   'cancel reservation',
#   'roll dice',
#   'rewards balance',
#   'repeat',
#   'pay bill',
#   'traffic',
#   'payday',
#   'timer',
#   'tire change',
#   'uber',
#   'oil change when',
#   'interest rate',
#   'confirm reservation',
#   'restaurant reservation',
#   'meeting schedule',
#   'bill due',
#   'international fees',
#   'find phone',
#   'change user name',
#   'pto request',
#   'routing',
#   'report fraud',
#   'sync device',
#   'redeem rewards',
#   'international visa',
#   'direct deposit',
#   'flight status',
#   'travel notification',
#   'what song',
#   'w2',
#   'travel alert',
#   'book flight',
#   'transactions',
#   'book hotel',
#   'schedule meeting',
#   'change accent',
#   'schedule maintenance',
#   'account blocked',
#   'card declined',
#   'pto request status',
#   'play music',
#   'damaged card',
#   'credit limit change',
#   'insurance change',
#   'freeze account',
#   'make call',
#   'car rental',
#   'change speed',
#   'change ai name',
#   'order checks',
#   'plug type',
#   'whisper mode',
#   'transfer',
#   'application status',
#   'reset settings',
#   'report lost card',
#   'new card',
#   'replacement card duration',
#   'change language',
#   'alarm',
#   'update playlist',
#   'pin change',
#   'next song',
#   'change volume'],
#  'cancel': ['cancel',
#   'cancel reservation',
#   'reset settings',
#   'freeze account',
#   'calendar update',
#   'confirm reservation',
#   'repeat',
#   'change language',
#   'restaurant reservation',
#   'no',
#   'whisper mode',
#   'reminder update',
#   'change speed',
#   'goodbye',
#   'make call',
#   'yes',
#   'change accent',
#   'maybe',
#   'thank you',
#   'pto request status',
#   'improve credit score',
#   'schedule meeting',
#   'expiration date',
#   'who made you',
#   'accept reservations',
#   'todo list',
#   'card declined',
#   'damaged card',
#   'flip coin',
#   'reminder',
#   'rollover 401k',
#   'balance',
#   'account blocked',
#   'greeting',
#   'meeting schedule',
#   'fun fact',
#   'who do you work for',
#   'payday',
#   'pin change',
#   'are you a bot',
#   'book hotel',
#   'calendar',
#   'lost luggage',
#   'play music',
#   'oil change how',
#   'tell joke',
#   'roll dice',
#   'sync device',
#   'pay bill',
#   'pto request',
#   'how old are you',
#   'text',
#   'todo list update',
#   'tire change',
#   'spelling',
#   'meaning of life',
#   'where are you from',
#   'change user name',
#   'what are your hobbies',
#   'calculator',
#   'credit score',
#   'timer',
#   'last maintenance',
#   'oil change when',
#   'do you have pets',
#   'change ai name',
#   'insurance change',
#   'date',
#   'report lost card',
#   'ingredients list',
#   'report fraud',
#   'jump start',
#   'shopping list',
#   'what can i ask you',
#   'smart home',
#   'recipe',
#   'next song',
#   'next holiday',
#   'find phone',
#   'share location',
#   'order',
#   'translate',
#   'schedule maintenance',
#   'shopping list update',
#   'credit limit change',
#   'travel notification',
#   'min payment',
#   'update playlist',
#   'apr',
#   'book flight',
#   'what is your name',
#   'change volume',
#   'income',
#   'what song',
#   'bill due',
#   'application status',
#   'travel suggestion',
#   'user name',
#   'transfer',
#   'new card',
#   'definition',
#   'meal suggestion',
#   'tire pressure',
#   'food last',
#   'w2',
#   'weather',
#   'credit limit',
#   'uber',
#   'measurement conversion',
#   'pto used',
#   'direct deposit',
#   'car rental',
#   'order status',
#   'transactions',
#   'taxes',
#   'replacement card duration',
#   'pto balance',
#   'calories',
#   'insurance',
#   'flight status',
#   'redeem rewards',
#   'ingredient substitution',
#   'international visa',
#   'vaccines',
#   'order checks',
#   'nutrition info',
#   'bill balance',
#   'gas',
#   'routing',
#   'timezone',
#   'mpg',
#   'how busy',
#   'spending history',
#   'plug type',
#   'cook time',
#   'rewards balance',
#   'restaurant suggestion',
#   'current location',
#   'traffic',
#   'gas type',
#   'interest rate',
#   'time',
#   'international fees',
#   'alarm',
#   'exchange rate',
#   'travel alert',
#   'distance',
#   'restaurant reviews',
#   'carry on',
#   'directions'],
#  'cancel reservation': ['cancel reservation',
#   'cancel',
#   'confirm reservation',
#   'calendar update',
#   'restaurant reservation',
#   'freeze account',
#   'accept reservations',
#   'damaged card',
#   'no',
#   'maybe',
#   'yes',
#   'pto request',
#   'schedule meeting',
#   'pto request status',
#   'greeting',
#   'calendar',
#   'thank you',
#   'card declined',
#   'reminder',
#   'expiration date',
#   'goodbye',
#   'book flight',
#   'make call',
#   'fun fact',
#   'travel notification',
#   'pin change',
#   'payday',
#   'reminder update',
#   'schedule maintenance',
#   'spelling',
#   'meeting schedule',
#   'date',
#   'next holiday',
#   'application status',
#   'order',
#   'bill due',
#   'pay bill',
#   'repeat',
#   'smart home',
#   'tell joke',
#   'book hotel',
#   'account blocked',
#   'flight status',
#   'reset settings',
#   'play music',
#   'text',
#   'pto balance',
#   'replacement card duration',
#   'change user name',
#   'uber',
#   'how old are you',
#   'how busy',
#   'next song',
#   'balance',
#   'translate',
#   'who do you work for',
#   'are you a bot',
#   'where are you from',
#   'what are your hobbies',
#   'credit limit change',
#   'definition',
#   'meal suggestion',
#   'lost luggage',
#   'share location',
#   'min payment',
#   'timer',
#   'meaning of life',
#   'order status',
#   'what is your name',
#   'report lost card',
#   'restaurant reviews',
#   'improve credit score',
#   'todo list',
#   'weather',
#   'restaurant suggestion',
#   'insurance',
#   'change accent',
#   'do you have pets',
#   'bill balance',
#   'pto used',
#   'change speed',
#   'rollover 401k',
#   'w2',
#   'last maintenance',
#   'recipe',
#   'apr',
#   'travel suggestion',
#   'taxes',
#   'alarm',
#   'whisper mode',
#   'what can i ask you',
#   'sync device',
#   'credit limit',
#   'credit score',
#   'flip coin',
#   'change ai name',
#   'time',
#   'todo list update',
#   'order checks',
#   'oil change when',
#   'calculator',
#   'what song',
#   'ingredients list',
#   'transactions',
#   'transfer',
#   'traffic',
#   'new card',
#   'insurance change',
#   'shopping list update',
#   'user name',
#   'carry on',
#   'travel alert',
#   'food last',
#   'report fraud',
#   'change language',
#   'direct deposit',
#   'find phone',
#   'car rental',
#   'shopping list',
#   'nutrition info',
#   'roll dice',
#   'international visa',
#   'timezone',
#   'who made you',
#   'tire change',
#   'current location',
#   'vaccines',
#   'change volume',
#   'rewards balance',
#   'income',
#   'redeem rewards',
#   'calories',
#   'oil change how',
#   'routing',
#   'gas',
#   'international fees',
#   'directions',
#   'tire pressure',
#   'update playlist',
#   'spending history',
#   'jump start',
#   'distance',
#   'interest rate',
#   'ingredient substitution',
#   'cook time',
#   'mpg',
#   'plug type',
#   'gas type',
#   'measurement conversion',
#   'exchange rate'],
#  'car rental': ['car rental',
#   'book hotel',
#   'spelling',
#   'fun fact',
#   'meal suggestion',
#   'uber',
#   'maybe',
#   'yes',
#   'what can i ask you',
#   'thank you',
#   'no',
#   'definition',
#   'where are you from',
#   'greeting',
#   'meaning of life',
#   'travel notification',
#   'what are your hobbies',
#   'tell joke',
#   'insurance',
#   'mpg',
#   'pto request',
#   'share location',
#   'directions',
#   'do you have pets',
#   'calculator',
#   'how old are you',
#   'what is your name',
#   'who do you work for',
#   'last maintenance',
#   'travel suggestion',
#   'goodbye',
#   'book flight',
#   'taxes',
#   'nutrition info',
#   'translate',
#   'cancel reservation',
#   'restaurant suggestion',
#   'are you a bot',
#   'rollover 401k',
#   'calendar',
#   'interest rate',
#   'new card',
#   'pay bill',
#   'date',
#   'income',
#   'order',
#   'reminder',
#   'who made you',
#   'jump start',
#   'lost luggage',
#   'travel alert',
#   'direct deposit',
#   'credit score',
#   'what song',
#   'cancel',
#   'schedule maintenance',
#   'schedule meeting',
#   'make call',
#   'payday',
#   'weather',
#   'carry on',
#   'min payment',
#   'next holiday',
#   'insurance change',
#   'flip coin',
#   'text',
#   'current location',
#   'recipe',
#   'international visa',
#   'reminder update',
#   'improve credit score',
#   'tire change',
#   'timer',
#   'play music',
#   'shopping list',
#   'calendar update',
#   'pto balance',
#   'w2',
#   'spending history',
#   'time',
#   'balance',
#   'repeat',
#   'user name',
#   'apr',
#   'vaccines',
#   'application status',
#   'pto request status',
#   'roll dice',
#   'change user name',
#   'gas',
#   'confirm reservation',
#   'oil change how',
#   'gas type',
#   'credit limit',
#   'find phone',
#   'damaged card',
#   'tire pressure',
#   'traffic',
#   'change ai name',
#   'card declined',
#   'routing',
#   'report fraud',
#   'distance',
#   'pto used',
#   'timezone',
#   'ingredients list',
#   'expiration date',
#   'change accent',
#   'calories',
#   'todo list',
#   'report lost card',
#   'oil change when',
#   'freeze account',
#   'account blocked',
#   'bill balance',
#   'international fees',
#   'flight status',
#   'restaurant reviews',
#   'todo list update',
#   'transactions',
#   'meeting schedule',
#   'shopping list update',
#   'credit limit change',
#   'restaurant reservation',
#   'measurement conversion',
#   'redeem rewards',
#   'order status',
#   'rewards balance',
#   'how busy',
#   'accept reservations',
#   'exchange rate',
#   'update playlist',
# ...
#   'where are you from',
#   'no',
#   'tell joke',
#   'definition',
#   'translate',
#   'how old are you',
#   'greeting',
#   'maybe',
#   'meaning of life',
#   'are you a bot',
#   'do you have pets',
#   'next song',
#   'share location',
#   'reminder',
#   'thank you',
#   'what are your hobbies',
#   'who do you work for',
#   'who made you',
#   'change ai name',
#   'calculator',
#   'date',
#   'last maintenance',
#   'goodbye',
#   'change user name',
#   'what can i ask you',
#   'repeat',
#   'change accent',
#   'current location',
#   'calendar',
#   'travel suggestion',
#   'find phone',
#   'timezone',
#   'time',
#   'make call',
#   'lost luggage',
#   'ingredients list',
#   'flip coin',
#   'next holiday',
#   'weather',
#   'nutrition info',
#   'recipe',
#   'roll dice',
#   'update playlist',
#   'oil change how',
#   'text',
#   'directions',
#   'credit score',
#   'calories',
#   'report fraud',
#   'pto used',
#   'pay bill',
#   'schedule meeting',
#   'car rental',
#   'cancel',
#   'meal suggestion',
#   'improve credit score',
#   'mpg',
#   'income',
#   'jump start',
#   'whisper mode',
#   'restaurant suggestion',
#   'shopping list',
#   'taxes',
#   'rollover 401k',
#   'w2',
#   'payday',
#   'min payment',
#   'travel notification',
#   'traffic',
#   'reminder update',
#   'damaged card',
#   'order',
#   'how busy',
#   'distance',
#   'todo list',
#   'apr',
#   'credit limit',
#   'vaccines',
#   'expiration date',
#   'oil change when',
#   'account blocked',
#   'gas',
#   'tire pressure',
#   'balance',
#   'uber',
#   'food last',
#   'change speed',
#   'book hotel',
#   'pto balance',
#   'gas type',
#   'measurement conversion',
#   'meeting schedule',
#   'tire change',
#   'transactions',
#   'spending history',
#   'international visa',
#   'carry on',
#   'schedule maintenance',
#   'travel alert',
#   'routing',
#   'exchange rate',
#   'bill balance',
#   'insurance',
#   'sync device',
#   'order status',
#   'book flight',
#   'smart home',
#   'pto request',
#   'flight status',
#   'cook time',
#   'shopping list update',
#   'cancel reservation',
#   'direct deposit',
#   'application status',
#   'plug type',
#   'report lost card',
#   'freeze account',
#   'card declined',
#   'international fees',
#   'insurance change',
#   'interest rate',
#   'transfer',
#   'bill due',
#   'ingredient substitution',
#   'calendar update',
#   'change language',
#   'rewards balance',
#   'confirm reservation',
#   'redeem rewards',
#   'todo list update',
#   'pto request status',
#   'restaurant reservation',
#   'restaurant reviews',
#   'timer',
#   'change volume',
#   'new card',
#   'credit limit change',
#   'alarm',
#   'replacement card duration',
#   'accept reservations',
#   'reset settings',
#   'order checks',
#   'pin change'],
#  'where are you from': ['where are you from',
#   'how old are you',
#   'what is your name',
#   'who made you',
#   'user name',
#   'fun fact',
#   'meaning of life',
#   'do you have pets',
#   'what can i ask you',
#   'thank you',
#   'what are your hobbies',
#   'spelling',
#   'who do you work for',
#   'current location',
#   'yes',
#   'no',
#   'are you a bot',
#   'share location',
#   'definition',
#   'translate',
#   'travel suggestion',
#   'time',
#   'timezone',
#   'greeting',
#   'what song',
#   'last maintenance',
#   'calculator',
#   'change ai name',
#   'balance',
#   'income',
#   'credit score',
#   'maybe',
#   'goodbye',
#   'insurance',
#   'date',
#   'tell joke',
#   'taxes',
#   'restaurant suggestion',
#   'change user name',
#   'directions',
#   'rollover 401k',
#   'change accent',
#   'international visa',
#   'recipe',
#   'spending history',
#   'distance',
#   'weather',
#   'nutrition info',
#   'ingredients list',
#   'play music',
#   'plug type',
#   'find phone',
#   'reminder',
#   'vaccines',
#   'repeat',
#   'w2',
#   'pto used',
#   'restaurant reviews',
#   'lost luggage',
#   'report fraud',
#   'apr',
#   'gas type',
#   'oil change how',
#   'measurement conversion',
#   'mpg',
#   'tire pressure',
#   'flip coin',
#   'pto balance',
#   'meal suggestion',
#   'improve credit score',
#   'calories',
#   'flight status',
#   'transactions',
#   'roll dice',
#   'text',
#   'shopping list',
#   'routing',
#   'cancel',
#   'report lost card',
#   'todo list',
#   'traffic',
#   'next holiday',
#   'jump start',
#   'how busy',
#   'travel notification',
#   'tire change',
#   'application status',
#   'make call',
#   'travel alert',
#   'interest rate',
#   'gas',
#   'credit limit',
#   'expiration date',
#   'payday',
#   'calendar',
#   'min payment',
#   'car rental',
#   'exchange rate',
#   'pay bill',
#   'rewards balance',
#   'damaged card',
#   'account blocked',
#   'bill balance',
#   'international fees',
#   'direct deposit',
#   'food last',
#   'book flight',
#   'order',
#   'oil change when',
#   'smart home',
#   'book hotel',
#   'pto request',
#   'order status',
#   'reminder update',
#   'change speed',
#   'cancel reservation',
#   'redeem rewards',
#   'pto request status',
#   'schedule meeting',
#   'whisper mode',
#   'credit limit change',
#   'freeze account',
#   'cook time',
#   'update playlist',
#   'next song',
#   'carry on',
#   'new card',
#   'schedule maintenance',
#   'insurance change',
#   'meeting schedule',
#   'uber',
#   'transfer',
#   'change language',
#   'card declined',
#   'sync device',
#   'replacement card duration',
#   'reset settings',
#   'todo list update',
#   'confirm reservation',
#   'ingredient substitution',
#   'bill due',
#   'restaurant reservation',
#   'shopping list update',
#   'timer',
#   'pin change',
#   'calendar update',
#   'order checks',
#   'alarm',
#   'change volume',
#   'accept reservations'],
#  'whisper mode': ['whisper mode',
#   'change volume',
#   'fun fact',
#   'yes',
#   'thank you',
#   'meaning of life',
#   'no',
#   'maybe',
#   'spelling',
#   'goodbye',
#   'change language',
#   'who made you',
#   'tell joke',
#   'change accent',
#   'play music',
#   'where are you from',
#   'are you a bot',
#   'change speed',
#   'repeat',
#   'greeting',
#   'definition',
#   'who do you work for',
#   'what are your hobbies',
#   'how old are you',
#   'do you have pets',
#   'what is your name',
#   'last maintenance',
#   'what can i ask you',
#   'next holiday',
#   'smart home',
#   'make call',
#   'cancel',
#   'translate',
#   'calculator',
#   'change ai name',
#   'flip coin',
#   'share location',
#   'what song',
#   'next song',
#   'text',
#   'travel suggestion',
#   'user name',
#   'change user name',
#   'rollover 401k',
#   'update playlist',
#   'pto request',
#   'reminder update',
#   'cancel reservation',
#   'reminder',
#   'find phone',
#   'freeze account',
#   'improve credit score',
#   'roll dice',
#   'lost luggage',
#   'schedule meeting',
#   'damaged card',
#   'recipe',
#   'credit score',
#   'report fraud',
#   'meal suggestion',
#   'oil change how',
#   'income',
#   'weather',
#   'schedule maintenance',
#   'account blocked',
#   'order',
#   'balance',
#   'jump start',
#   'taxes',
#   'pay bill',
#   'report lost card',
#   'insurance',
#   'date',
#   'min payment',
#   'oil change when',
#   'calendar',
#   'todo list',
#   'application status',
#   'nutrition info',
#   'book flight',
#   'shopping list update',
#   'sync device',
#   'alarm',
#   'meeting schedule',
#   'ingredients list',
#   'timezone',
#   'timer',
#   'pto used',
#   'w2',
#   'reset settings',
#   'tire pressure',
#   'restaurant suggestion',
#   'flight status',
#   'uber',
#   'current location',
#   'routing',
#   'travel notification',
#   'card declined',
#   'order status',
#   'calendar update',
#   'tire change',
#   'apr',
#   'confirm reservation',
#   'credit limit',
#   'calories',
#   'shopping list',
#   'mpg',
#   'book hotel',
#   'todo list update',
#   'measurement conversion',
#   'payday',
#   'directions',
#   'time',
#   'pto balance',
#   'how busy',
#   'gas',
#   'vaccines',
#   'car rental',
#   'expiration date',
#   'spending history',
#   'interest rate',
#   'food last',
#   'gas type',
#   'rewards balance',
#   'travel alert',
#   'redeem rewards',
#   'bill balance',
#   'credit limit change',
#   'insurance change',
#   'transactions',
#   'direct deposit',
#   'distance',
#   'restaurant reviews',
#   'new card',
#   'transfer',
#   'traffic',
#   'pto request status',
#   'ingredient substitution',
#   'international visa',
#   'cook time',
#   'restaurant reservation',
#   'carry on',
#   'bill due',
#   'international fees',
#   'plug type',
#   'pin change',
#   'exchange rate',
#   'replacement card duration',
#   'order checks',
#   'accept reservations'],
#  'who do you work for': ['who do you work for',
#   'who made you',
#   'thank you',
#   'fun fact',
#   'no',
#   'where are you from',
#   'definition',
#   'do you have pets',
#   'what are your hobbies',
#   'what can i ask you',
#   'how old are you',
#   'tell joke',
#   'yes',
#   'what is your name',
#   'report fraud',
#   'report lost card',
#   'meaning of life',
#   'are you a bot',
#   'maybe',
#   'greeting',
#   'translate',
#   'spelling',
#   'goodbye',
#   'calculator',
#   'last maintenance',
#   'income',
#   'taxes',
#   'user name',
#   'next holiday',
#   'current location',
#   'credit score',
#   'balance',
#   'date',
#   'damaged card',
#   'roll dice',
#   'share location',
#   'rollover 401k',
#   'reminder',
#   'make call',
#   'todo list',
#   'play music',
#   'cancel',
#   'insurance',
#   'text',
#   'lost luggage',
#   'spending history',
#   'flip coin',
#   'w2',
#   'schedule meeting',
#   'direct deposit',
#   'what song',
#   'oil change how',
#   'change accent',
#   'nutrition info',
#   'repeat',
#   'travel alert',
#   'replacement card duration',
#   'improve credit score',
#   'application status',
#   'find phone',
#   'apr',
#   'change user name',
#   'payday',
#   'recipe',
#   'routing',
#   'travel suggestion',
#   'pto used',
#   'tire pressure',
#   'account blocked',
#   'timezone',
#   'pay bill',
#   'calendar',
#   'order status',
#   'tire change',
#   'transactions',
#   'oil change when',
#   'pto request',
#   'meeting schedule',
#   'change ai name',
#   'travel notification',
#   'reminder update',
#   'credit limit',
#   'schedule maintenance',
#   'ingredients list',
#   'jump start',
#   'freeze account',
#   'mpg',
#   'min payment',
#   'pto balance',
#   'interest rate',
#   'smart home',
#   'bill balance',
#   'meal suggestion',
#   'calories',
#   'expiration date',
#   'time',
#   'next song',
#   'shopping list',
#   'weather',
#   'gas',
#   'flight status',
#   'whisper mode',
#   'card declined',
#   'vaccines',
#   'gas type',
#   'todo list update',
#   'order',
#   'how busy',
#   'change speed',
#   'sync device',
#   'distance',
#   'international visa',
#   'car rental',
#   'food last',
#   'uber',
#   'directions',
#   'new card',
#   'cancel reservation',
#   'insurance change',
#   'pto request status',
#   'measurement conversion',
#   'traffic',
#   'rewards balance',
#   'timer',
#   'plug type',
#   'shopping list update',
#   'reset settings',
#   'transfer',
#   'redeem rewards',
#   'update playlist',
#   'restaurant suggestion',
#   'book flight',
#   'credit limit change',
#   'bill due',
#   'international fees',
#   'restaurant reviews',
#   'order checks',
#   'book hotel',
#   'pin change',
#   'exchange rate',
#   'calendar update',
#   'alarm',
#   'change volume',
#   'cook time',
#   'ingredient substitution',
#   'confirm reservation',
#   'change language',
#   'carry on',
#   'restaurant reservation',
#   'accept reservations'],
#  'who made you': ['who made you',
#   'who do you work for',
#   'thank you',
#   'where are you from',
#   'how old are you',
#   'fun fact',
#   'yes',
#   'what can i ask you',
#   'meaning of life',
#   'spelling',
#   'what is your name',
#   'no',
#   'are you a bot',
#   'do you have pets',
#   'definition',
#   'maybe',
#   'goodbye',
#   'tell joke',
#   'what are your hobbies',
#   'greeting',
#   'user name',
#   'calculator',
#   'translate',
#   'last maintenance',
#   'ingredients list',
#   'flip coin',
#   'cancel',
#   'taxes',
#   'report fraud',
#   'repeat',
#   'improve credit score',
#   'income',
#   'roll dice',
#   'credit score',
#   'what song',
#   'text',
#   'recipe',
#   'change ai name',
#   'change accent',
#   'rollover 401k',
#   'next holiday',
#   'apr',
#   'lost luggage',
#   'damaged card',
#   'find phone',
#   'play music',
#   'report lost card',
#   'date',
#   'travel suggestion',
#   'schedule meeting',
#   'share location',
#   'freeze account',
#   'oil change how',
#   'nutrition info',
#   'reminder',
#   'card declined',
#   'reminder update',
#   'pto used',
#   'calories',
#   'credit limit',
#   'balance',
#   'jump start',
#   'meal suggestion',
#   'pto request',
#   'min payment',
#   'account blocked',
#   'order',
#   'w2',
#   'change user name',
#   'whisper mode',
#   'spending history',
#   'timezone',
#   'cancel reservation',
#   'measurement conversion',
#   'weather',
#   'transactions',
#   'vaccines',
#   'calendar',
#   'tire change',
#   'pay bill',
#   'smart home',
#   'mpg',
#   'tire pressure',
#   'international visa',
#   'direct deposit',
#   'car rental',
#   'bill balance',
#   'oil change when',
#   'sync device',
#   'how busy',
#   'routing',
#   'application status',
#   'make call',
#   'current location',
#   'transfer',
#   'payday',
#   'book flight',
#   'time',
#   'timer',
#   'shopping list',
#   'new card',
#   'insurance',
#   'travel notification',
#   'expiration date',
#   'pto balance',
#   'interest rate',
#   'reset settings',
#   'directions',
#   'international fees',
#   'traffic',
#   'schedule maintenance',
#   'todo list',
#   'redeem rewards',
#   'flight status',
#   'change speed',
#   'insurance change',
#   'next song',
#   'cook time',
#   'replacement card duration',
#   'update playlist',
#   'food last',
#   'pto request status',
#   'distance',
#   'gas',
#   'uber',
#   'rewards balance',
#   'credit limit change',
#   'order status',
#   'bill due',
#   'gas type',
#   'restaurant suggestion',
#   'exchange rate',
#   'plug type',
#   'shopping list update',
#   'meeting schedule',
#   'change volume',
#   'ingredient substitution',
#   'restaurant reviews',
#   'book hotel',
#   'travel alert',
#   'calendar update',
#   'confirm reservation',
#   'todo list update',
#   'alarm',
#   'change language',
#   'pin change',
#   'restaurant reservation',
#   'order checks',
#   'carry on',
#   'accept reservations'],
#  'yes': ['yes',
#   'no',
#   'thank you',
#   'spelling',
#   'fun fact',
#   'who made you',
#   'what can i ask you',
#   'are you a bot',
#   'maybe',
#   'tell joke',
#   'goodbye',
#   'flip coin',
#   'meaning of life',
#   'how old are you',
#   'where are you from',
#   'directions',
#   'definition',
#   'do you have pets',
#   'what are your hobbies',
#   'what is your name',
#   'change accent',
#   'greeting',
#   'translate',
#   'repeat',
#   'who do you work for',
#   'last maintenance',
#   'rollover 401k',
#   'book flight',
#   'report lost card',
#   'roll dice',
#   'play music',
#   'report fraud',
#   'lost luggage',
#   'cancel',
#   'calculator',
#   'what song',
#   'change ai name',
#   'reset settings',
#   'freeze account',
#   'card declined',
#   'damaged card',
#   'reminder',
#   'meal suggestion',
#   'payday',
#   'recipe',
#   'improve credit score',
#   'cancel reservation',
#   'oil change how',
#   'smart home',
#   'text',
#   'apr',
#   'change user name',
#   'oil change when',
#   'user name',
#   'nutrition info',
#   'income',
#   'pay bill',
#   'find phone',
#   'account blocked',
#   'share location',
#   'pto request',
#   'schedule maintenance',
#   'direct deposit',
#   'ingredients list',
#   'balance',
#   'change speed',
#   'taxes',
#   'next holiday',
#   'next song',
#   'whisper mode',
#   'jump start',
#   'travel suggestion',
#   'credit score',
#   'travel notification',
#   'tire pressure',
#   'change language',
#   'insurance change',
#   'shopping list',
#   'tire change',
#   'schedule meeting',
#   'order',
#   'todo list',
#   'transfer',
#   'calories',
#   'change volume',
#   'calendar',
#   'credit limit change',
#   'w2',
#   'shopping list update',
#   'sync device',
#   'min payment',
#   'weather',
#   'interest rate',
#   'new card',
#   'international visa',
#   'credit limit',
#   'make call',
#   'spending history',
#   'application status',
#   'date',
#   'expiration date',
#   'mpg',
#   'update playlist',
#   'routing',
#   'food last',
#   'transactions',
#   'vaccines',
#   'measurement conversion',
#   'how busy',
#   'uber',
#   'current location',
#   'reminder update',
#   'insurance',
#   'pto balance',
#   'distance',
#   'calendar update',
#   'ingredient substitution',
#   'timezone',
#   'restaurant suggestion',
#   'traffic',
#   'pto used',
#   'flight status',
#   'replacement card duration',
#   'pin change',
#   'pto request status',
#   'todo list update',
#   'timer',
#   'redeem rewards',
#   'order checks',
#   'bill balance',
#   'gas type',
#   'car rental',
#   'gas',
#   'restaurant reviews',
#   'alarm',
#   'time',
#   'confirm reservation',
#   'bill due',
#   'travel alert',
#   'order status',
#   'international fees',
#   'plug type',
#   'restaurant reservation',
#   'book hotel',
#   'meeting schedule',
#   'exchange rate',
#   'cook time',
#   'rewards balance',
#   'carry on',
#   'accept reservations']}

# %%
dct = {"id": [], "intent": []}
for i, j in enumerate(list(prediction)):
    dct["id"].append(i)
    dct["intent"].append(j)

# %%
def dict_to_dataset(dict):
    dataset = datasets.Dataset.from_dict(dict)
    return dataset

pred = dict_to_dataset(dct)
pred.save_to_disk(f"pred_xlmr")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/2239 [00:00<?, ? examples/s]

# %%
acc_lst = labels == prediction

# %%
print(f"Accuracy = {acc_lst.sum()/2239}")
# Out:
# Accuracy = 0.8311746120452881

# %%
labels.view(-1, 1) in torch.argsort(scores, dim=1)[:, :10]
# Out:
# True

# %%
prediction
# Out:
# tensor([101, 109,   3,  ...,  47,   6,   3])
